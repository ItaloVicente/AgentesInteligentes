# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
burro = pd.read_csv('robo_burro4x4.csv')
inteligente = pd.read_csv('robo_inteligente4x4.csv')

# %%
burro, inteligente
# Out:
# (   Iteração  Acertos  Erros  Movimentos Realizados
#  0         1     50.0  525.0                  185.0
#  1         2     50.0  986.0                  337.0
#  2         3     50.0  103.0                   42.0
#  3         4     50.0   41.0                   21.0
#  4         5     50.0  362.0                  129.0
#  5         6     50.0   33.0                   18.0
#  6         7     50.0  119.0                   49.0
#  7         8     50.0  181.0                   68.0
#  8         9     50.0  227.0                   84.0
#  9        10     50.0  203.0                   76.0
#  10    Média     50.0  278.0                    NaN,
#     Iteração  Acertos  Erros  Movimentos Realizados
#  0         1     50.0    8.0                   13.0
#  1         2     50.0   13.0                   14.0
#  2         3     50.0   28.0                   19.0
#  3         4     50.0   80.0                   37.0
#  4         5     50.0    7.0                   10.0
#  5         6     50.0   19.0                   16.0
#  6         7     50.0   11.0                   12.0
#  7         8     50.0    7.0                   10.0
#  8         9     50.0   13.0                   12.0
#  9        10     50.0   41.0                   22.0
#  10    Média     50.0   22.7                    NaN)

# %%
robo_burro = burro[burro['Iteração'] != 'Média']
robo_inteligente = inteligente[inteligente['Iteração'] != 'Média']

for col in ['Acertos', 'Erros', 'Movimentos Realizados']:
    robo_burro[col] = pd.to_numeric(robo_burro[col], errors='coerce')
    robo_inteligente[col] = pd.to_numeric(robo_inteligente[col], errors='coerce')

plt.figure(figsize=(14, 6))


plt.subplot(1, 3, 2)
plt.plot(robo_burro['Iteração'], robo_burro['Erros'], label='Robo Burro')
plt.plot(robo_inteligente['Iteração'], robo_inteligente['Erros'], label='Robo Inteligente')
plt.title('Comparação de Erros')
plt.xlabel('Iteração')
plt.ylabel('Erros')
plt.legend()
plt.xticks(ticks=range(0, len(robo_burro['Iteração']), 2)) 

plt.subplot(1, 3, 3)
plt.plot(robo_burro['Iteração'], robo_burro['Movimentos Realizados'], label='Robo Burro')
plt.plot(robo_inteligente['Iteração'], robo_inteligente['Movimentos Realizados'], label='Robo Inteligente')
plt.title('Comparação de Movimentos Realizados')
plt.xlabel('Iteração')
plt.ylabel('Movimentos Realizados')
plt.legend()
plt.xticks(ticks=range(0, len(robo_burro['Iteração']), 2))  # Mostrar apenas algumas marcas no eixo X

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_82724/2021438017.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   robo_burro[col] = pd.to_numeric(robo_burro[col], errors='coerce')
# /tmp/ipykernel_82724/2021438017.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   robo_inteligente[col] = pd.to_numeric(robo_inteligente[col], errors='coerce')

# %%
import pandas as pd
import matplotlib.pyplot as plt

robo_burro = pd.read_csv('robo_burro3x3.csv')
robo_inteligente = pd.read_csv('robo_inteligente3x3.csv')

robo_burro = robo_burro[robo_burro['Iteração'] != 'Média']
robo_inteligente = robo_inteligente[robo_inteligente['Iteração'] != 'Média']

for col in ['Acertos', 'Erros', 'Movimentos Realizados']:
    robo_burro[col] = pd.to_numeric(robo_burro[col], errors='coerce')
    robo_inteligente[col] = pd.to_numeric(robo_inteligente[col], errors='coerce')

plt.figure(figsize=(14, 6))


plt.subplot(1, 3, 2)
plt.plot(robo_burro['Iteração'], robo_burro['Erros'], label='Robo Burro')
plt.plot(robo_inteligente['Iteração'], robo_inteligente['Erros'], label='Robo Inteligente')
plt.title('Comparação de Erros')
plt.xlabel('Iteração')
plt.ylabel('Erros')
plt.legend()
plt.xticks(ticks=range(0, len(robo_burro['Iteração']), 2)) 

plt.subplot(1, 3, 3)
plt.plot(robo_burro['Iteração'], robo_burro['Movimentos Realizados'], label='Robo Burro')
plt.plot(robo_inteligente['Iteração'], robo_inteligente['Movimentos Realizados'], label='Robo Inteligente')
plt.title('Comparação de Movimentos Realizados')
plt.xlabel('Iteração')
plt.ylabel('Movimentos Realizados')
plt.legend()
plt.xticks(ticks=range(0, len(robo_burro['Iteração']), 2))  # Mostrar apenas algumas marcas no eixo X

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

robo_burro = pd.read_csv('robo_burro5x5.csv')
robo_inteligente = pd.read_csv('robo_inteligente5x5.csv')

robo_burro = robo_burro[robo_burro['Iteração'] != 'Média']
robo_inteligente = robo_inteligente[robo_inteligente['Iteração'] != 'Média']

for col in ['Acertos', 'Erros', 'Movimentos Realizados']:
    robo_burro[col] = pd.to_numeric(robo_burro[col], errors='coerce')
    robo_inteligente[col] = pd.to_numeric(robo_inteligente[col], errors='coerce')

plt.figure(figsize=(14, 6))


plt.subplot(1, 3, 2)
plt.plot(robo_burro['Iteração'], robo_burro['Erros'], label='Robo Burro')
plt.plot(robo_inteligente['Iteração'], robo_inteligente['Erros'], label='Robo Inteligente')
plt.title('Comparação de Erros')
plt.xlabel('Iteração')
plt.ylabel('Erros')
plt.legend()
plt.xticks(ticks=range(0, len(robo_burro['Iteração']), 2)) 

plt.subplot(1, 3, 3)
plt.plot(robo_burro['Iteração'], robo_burro['Movimentos Realizados'], label='Robo Burro')
plt.plot(robo_inteligente['Iteração'], robo_inteligente['Movimentos Realizados'], label='Robo Inteligente')
plt.title('Comparação de Movimentos Realizados')
plt.xlabel('Iteração')
plt.ylabel('Movimentos Realizados')
plt.legend()
plt.xticks(ticks=range(0, len(robo_burro['Iteração']), 2))  # Mostrar apenas algumas marcas no eixo X

plt.tight_layout()
plt.show()
